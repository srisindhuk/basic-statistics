# %%
import numpy as np
import pandas as pd
df = pd.read_csv("seeds.csv")
df
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    14.88      14.57       0.8811          5.554         3.333
# 2    14.29      14.09       0.9050          5.291         3.337
# 3    13.84      13.94       0.8955          5.324         3.379
# 4    16.14      14.99       0.9034          5.658         3.562
# ..     ...        ...          ...            ...           ...
# 194  12.19      13.20       0.8783          5.137         2.981
# 195  11.23      12.88       0.8511          5.140         2.795
# 196  13.20      13.66       0.8883          5.236         3.232
# 197  11.84      13.21       0.8521          5.175         2.836
# 198  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 0              2.221          5.220     1
# 1              1.018          4.956     1
# 2              2.699          4.825     1
# ...

# %%
df.mean()
# Out:
# Area               14.918744
# Perimeter          14.595829
# Compactness         0.870811
# Kernel.Length       5.643151
# Kernel.Width        3.265533
# Asymmetry.Coeff     3.699217
# Kernel.Groove       5.420653
# Type                1.994975
# dtype: float64

# %%
df.median()
# Out:
# Area               14.4300
# Perimeter          14.3700
# Compactness         0.8734
# Kernel.Length       5.5410
# Kernel.Width        3.2450
# Asymmetry.Coeff     3.6310
# Kernel.Groove       5.2280
# Type                2.0000
# dtype: float64

# %%
df.mode()
# Out:
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  11.23      13.47       0.8823          5.236         3.026
# 1    NaN        NaN          NaN          5.395           NaN
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.129          5.001   2.0
# 1            2.221            NaN   NaN

# %%
range = df.max()-df.min()
range
# Out:
# Area               10.5900
# Perimeter           4.8400
# Compactness         0.1102
# Kernel.Length       1.7760
# Kernel.Width        1.4030
# Asymmetry.Coeff     7.5499
# Kernel.Groove       2.0310
# Type                2.0000
# dtype: float64

# %%
print(df.var())
# Out:
# Area               8.526259
# Perimeter          1.717265
# Compactness        0.000544
# Kernel.Length      0.196775
# Kernel.Width       0.143127
# Asymmetry.Coeff    2.164142
# Kernel.Groove      0.242771
# Type               0.661591
# dtype: float64

# %%
print(df.std())
# Out:
# Area               2.919976
# Perimeter          1.310445
# Compactness        0.023320
# Kernel.Length      0.443593
# Kernel.Width       0.378322
# Asymmetry.Coeff    1.471102
# Kernel.Groove      0.492718
# Type               0.813382
# dtype: float64

# %%
df.quantile(q=0.25)                       # Returns the value below which 25% of the data lies.
# Out:
# Area               12.3300
# Perimeter          13.4700
# Compactness         0.8571
# Kernel.Length       5.2670
# Kernel.Width        2.9545
# Asymmetry.Coeff     2.5700
# Kernel.Groove       5.0460
# Type                1.0000
# Name: 0.25, dtype: float64

# %%
df.describe()
# Out:
#              Area   Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# count  199.000000  199.000000   199.000000     199.000000    199.000000
# mean    14.918744   14.595829     0.870811       5.643151      3.265533
# std      2.919976    1.310445     0.023320       0.443593      0.378322
# min     10.590000   12.410000     0.808100       4.899000      2.630000
# 25%     12.330000   13.470000     0.857100       5.267000      2.954500
# 50%     14.430000   14.370000     0.873400       5.541000      3.245000
# 75%     17.455000   15.805000     0.886800       6.002000      3.564500
# max     21.180000   17.250000     0.918300       6.675000      4.033000
#
#        Asymmetry.Coeff  Kernel.Groove        Type
# count       199.000000     199.000000  199.000000
# mean          3.699217       5.420653    1.994975
# std           1.471102       0.492718    0.813382
# min           0.765100       4.519000    1.000000
# 25%           2.570000       5.046000    1.000000
# ...
